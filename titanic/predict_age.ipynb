# %%
import pandas as pd
import numpy as np
import math
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

df = pd.read_csv("data/train.csv")

def map_sex(str):
    if (str == "male"):
        return 0
    else:
        return 1
    
def insert_age(row):
    if (math.isnan(row["Age"])):
        #print(row)
        #row["Age"] = lr.predict(
        r_d = row.drop(columns=["Name", "Cabin", "Ticket", "Embarked", "Survived", "Age"])
        print(r_d)
    return row
    

#trying out linear regression and a random forest regressor for age prediction
#df = df.drop(columns=["Name", "Cabin", "Ticket", "Embarked", "Survived"]).dropna()
#df["Sex"] = df["Sex"].map(map_sex)
#df_y = df["Age"]
#df_x = df.drop(columns="Age")
#
#lr = LinearRegression()
#rfr = RandomForestRegressor()
#
#print(cross_val_score(lr, df_x, df_y, cv=5).mean())
#
#print(cross_val_score(rfr, df_x, df_y, cv=5).mean())

df_1 = df.drop(columns=["Name", "Cabin", "Ticket", "Embarked", "Survived"]).dropna()
df_1["Sex"] = df_1["Sex"].map(map_sex)
df_y = df_1["Age"]
df_x = df_1.drop(columns="Age")



lr.fit(df_x, df_y)


df.apply(insert_age, axis=1)


#print(df)

df.to_csv("data/train_age_predicted.csv")
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object
# PassengerId                              18
# Survived                                  1
# Pclass                                    2
# Name           Williams, Mr. Charles Eugene
# Sex                                    male
# Age                                     NaN
# SibSp                                     0
# Parch                                     0
# Ticket                               244373
# Fare                                     13
# Cabin                                   NaN
# Embarked                                  S
# ...
